# %% [markdown]
# The goal is to apply the minimal flash attn implementation to LLMs in PyTorch/HuggingFace to benchmark their performance.
#
# Using `demo-flash-attention-minimal.ipynb` to start, but note that doesn't use LLMs at all, it only benchmarks the kernel alone.
#
# We want to benchmark the kernel **within** LLMs and compare with the defaults. Let's start with some setup:

# %% [markdown]
# ### Setup
# Note that we need python3.10 so that pybind works. Currently have python3.12. So, in terminal:
# ```bash
# source /project/engineering/anaconda3/etc/profile.d/conda.sh
# conda create -n py310 python=3.10
# conda activate py310
# conda install jupyter ipykernel
# pip3 install torch torchvision torchaudio
# pip install transformers
# pip install Ninja   # for building cuda
# python -m ipykernel install --user --name py310 --display-name "Python 3.10 (py310)"
# ```

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   myenv      /home/warehouse/cnicholas/.local/share/jupyter/kernels/myenv
#   py310      /home/warehouse/cnicholas/.local/share/jupyter/kernels/py310
#   python3    /opt/conda/share/jupyter/kernels/python3

# %% [markdown]
# Now change the kernel to `Python (myenv)` to work in our fresh environment. Probably need to close then reopen the notebook.

# %%
import torch
assert torch.cuda.is_available(), "You must have a GPU to run this notebook."
print("GPU available.")
# Out:
# GPU available.

# %% [markdown]
# ### Reused Code
# Below is copied from the notebook. We'll test and ensure it works. No need to run this

# %%
### Default Minimal Kernel Implementation copied from the notebook:
import os
import math

import torch
from torch.nn import functional as F
from torch.utils.cpp_extension import load_inline

cuda_src = '''
__global__
void forward_kernel(const float* Q, const float* K, const float* V, const int N, const int d,
                    const int Tc, const int Tr, const int Bc, const int Br, const float softmax_scale,
                    float* l, float *m, float* O) {
    int tx = threadIdx.x;
    int bx = blockIdx.x; int by = blockIdx.y;  // batch and head index

    // Offset into Q,K,V,O,l,m - different for each batch and head
    int qkv_offset = (bx * gridDim.y * N * d) + (by * N * d);  // gridDim.y = nh
    int lm_offset = (bx * gridDim.y * N) + (by * N);  // offset for l and m

    // Define SRAM for Q,K,V,S
    extern __shared__ float sram[];
    int tile_size = Bc * d;  // size of Qi, Kj, Vj
    float* Qi = sram;
    float* Kj = &sram[tile_size];
    float* Vj = &sram[tile_size * 2];
    float* S = &sram[tile_size * 3];

    for (int j = 0; j < Tc; j++) {

        // Load Kj, Vj to SRAM
        for (int x = 0; x < d; x++) {
            Kj[(tx * d) + x] = K[qkv_offset + (tile_size * j) + (tx * d) + x];
            Vj[(tx * d) + x] = V[qkv_offset + (tile_size * j) + (tx * d) + x];
        }
        __syncthreads();  // such that the inner loop can use the correct Kj, Vj

        for (int i = 0; i < Tr; i++)  {

            // Load Qi to SRAM, l and m to registers
            for (int x = 0; x < d; x++) {
                Qi[(tx * d) + x] = Q[qkv_offset + (tile_size * i) + (tx * d) + x];
            }
            float row_m_prev = m[lm_offset + (Br * i) + tx];
            float row_l_prev = l[lm_offset + (Br * i) + tx];

            // S = QK^T, row_m = rowmax(S)
            float row_m = -INFINITY;
            for (int y = 0; y < Bc; y++) {
                float sum = 0;
                for (int x = 0; x < d; x++) {
                    sum += Qi[(tx * d) + x] * Kj[(y * d) + x];
                }
                sum *= softmax_scale;
                S[(Bc * tx) + y] = sum;

                if (sum > row_m)
                    row_m = sum;
            }

            // P = exp(S - row_m), row_l = rowsum(P)
            float row_l = 0;
            for (int y = 0; y < Bc; y++) {
                S[(Bc * tx) + y] = __expf(S[(Bc * tx) + y] - row_m);
                row_l += S[(Bc * tx) + y];
            }

            // Compute new m and l
            float row_m_new = max(row_m_prev, row_m);
            float row_l_new = (__expf(row_m_prev - row_m_new) * row_l_prev) + (__expf(row_m - row_m_new) * row_l);

            // Write O, l, m to HBM
            for (int x = 0; x < d; x++) {
                float pv = 0;  // Pij * Vj
                for (int y = 0; y < Bc; y++) {
                    pv += S[(Bc * tx) + y] * Vj[(y * d) + x];
                }
                O[qkv_offset + (tile_size * i) + (tx * d) + x] = (1 / row_l_new) \
                    * ((row_l_prev * __expf(row_m_prev - row_m_new) * O[qkv_offset + (tile_size * i) + (tx * d) + x]) \
                    + (__expf(row_m - row_m_new) * pv));
            }
            m[lm_offset + (Br * i) + tx] = row_m_new;
            l[lm_offset + (Br * i) + tx] = row_l_new;
        }
        __syncthreads();  // otherwise, thread can use the wrong Kj, Vj in inner loop
    }
}

torch::Tensor forward(torch::Tensor Q, torch::Tensor K, torch::Tensor V) {
    // TODO: determine Bc, Br dynamically
    const int Bc = 32; const int Br = 32;

    const int B = Q.size(0); const int nh = Q.size(1);
    const int N = Q.size(2); const int d = Q.size(3);

    const int Tc = ceil((float) N / Bc); const int Tr = ceil((float) N / Br);
    const float softmax_scale = 1.0 / sqrt(d);

    // Initialize O, l, m to HBM
    auto O = torch::zeros_like(Q);
    auto l = torch::zeros({B, nh, N});
    auto m = torch::full({B, nh, N}, -INFINITY);
    torch::Device device(torch::kCUDA);
    l = l.to(device); m = m.to(device);

    // Calculate SRAM size needed per block
    const int sram_size = (3 * Bc * d * sizeof(float)) + (Bc * Br * sizeof(float));
    int max_sram_size;
    cudaDeviceGetAttribute(&max_sram_size, cudaDevAttrMaxSharedMemoryPerBlock, 0);
    printf("Max shared memory: %d, requested shared memory: %d \\n", max_sram_size, sram_size);

    dim3 grid_dim(B, nh);  // batch_size x num_heads
    dim3 block_dim(Bc);  // Bc threads per block

    forward_kernel<<<grid_dim, block_dim, sram_size>>>(
        Q.data_ptr<float>(), K.data_ptr<float>(), V.data_ptr<float>(),
        N, d, Tc, Tr, Bc, Br, softmax_scale,
        l.data_ptr<float>(), m.data_ptr<float>(), O.data_ptr<float>()
    );
    return O;
}
'''
cpp_src = 'torch::Tensor forward(torch::Tensor Q, torch::Tensor K, torch::Tensor V);'

build_dir = 'cuda'
if not os.path.exists(build_dir):
    os.mkdir(build_dir)

minimal_attn = load_inline(
    name='minimal_attn',
    cpp_sources=cpp_src,
    cuda_sources=cuda_src,
    functions=['forward'],
    with_cuda=True,
    extra_cuda_cflags=['-O2'],
    build_directory=f'./{build_dir}'
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(

# %%
# Notebook code test. Note this does not use an LLM.
batch_size = 32
n_head = 12
seq_len = 64
head_embd = 32

q = torch.randn(batch_size, n_head, seq_len, head_embd).cuda()
k = torch.randn(batch_size, n_head, seq_len, head_embd).cuda()
v = torch.randn(batch_size, n_head, seq_len, head_embd).cuda()

print('=== profiling manual attention ===')

# Our minimal flash attention needs to be faster than this.
def manual_attn(q, k, v):
    att = (q @ k.transpose(-2, -1) * (1.0 / math.sqrt(k.size(-1))))
    att = F.softmax(att, dim=-1)
    y = att @ v
    return y

with torch.autograd.profiler.profile(use_cuda=True) as prof:
    manual_result = manual_attn(q, k, v)
print(prof.key_averages().table(sort_by='cuda_time_total', row_limit=10))

print('=== profiling minimal flash attention === ')

with torch.autograd.profiler.profile(use_cuda=True) as prof:
    minimal_result = minimal_attn.forward(q, k, v)
print(prof.key_averages().table(sort_by='cuda_time_total', row_limit=10))

print('attn values sanity check:', torch.allclose(minimal_result, manual_result, rtol=0, atol=1e-02))
# Out:
# === profiling manual attention ===
# <ipython-input-5-5f21cbf2019f>:20: FutureWarning: The attribute `use_cuda` will be deprecated soon, please use ``use_device = 'cuda'`` instead.
#   with torch.autograd.profiler.profile(use_cuda=True) as prof:
# -------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                      aten::matmul         2.92%       6.357ms        68.67%     149.606ms      74.803ms       6.312ms         2.90%     149.696ms      74.848ms             2
#                                         aten::bmm        26.62%      57.984ms        62.81%     136.839ms      68.420ms     137.021ms        62.87%     137.021ms      68.510ms             2
#                                     aten::softmax         1.04%       2.264ms        16.27%      35.455ms      35.455ms       2.254ms         1.03%      35.470ms      35.470ms             1
#                                    aten::_softmax         1.36%       2.957ms        15.23%      33.180ms      33.180ms      33.216ms        15.24%      33.216ms      33.216ms             1
#                                         aten::mul         2.41%       5.241ms        13.90%      30.278ms      30.278ms      30.307ms        13.91%      30.307ms      30.307ms             1
#                                      aten::expand         1.47%       3.212ms         1.49%       3.249ms     812.272us       3.229ms         1.48%       3.262ms     815.500us             4
#                                   aten::transpose         0.30%     658.511us         1.13%       2.462ms       2.462ms     656.000us         0.30%       2.469ms       2.469ms             1
#                                     aten::reshape         0.97%       2.113ms         1.11%       2.407ms     601.849us       2.125ms         0.98%       2.422ms     605.500us             4
#                                  aten::as_strided         0.83%       1.806ms         0.83%       1.806ms     361.289us       1.846ms         0.85%       1.846ms     369.200us             5
#                                aten::_unsafe_view         0.31%     666.996us         0.31%     666.996us     333.498us     679.000us         0.31%     679.000us     339.500us             2
# -------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 217.856ms
# Self CUDA time total: 217.942ms
#
# === profiling minimal flash attention ===
# --------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                       Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# --------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#           aten::zeros_like         0.12%      36.010us        55.19%      16.202ms      16.202ms      42.000us         0.22%      16.207ms      16.207ms             1
#                aten::fill_        15.34%       4.502ms        48.29%      14.176ms       7.088ms      14.200ms        75.76%      14.200ms       7.100ms             2
#                aten::zero_         4.44%       1.305ms        46.51%      13.654ms       6.827ms       1.311ms         6.99%      13.661ms       6.830ms             2
#           aten::empty_like         8.63%       2.534ms         8.72%       2.559ms       2.559ms       2.539ms        13.55%       2.562ms       2.562ms             1
#                 aten::full         0.14%      41.822us         6.54%       1.921ms       1.921ms      37.000us         0.20%       1.926ms       1.926ms             1
#                   aten::to         0.05%      15.695us         1.72%     504.400us     252.200us      22.000us         0.12%     508.000us     254.000us             2
#             aten::_to_copy         0.20%      58.254us         1.64%     481.534us     240.767us      61.000us         0.33%     486.000us     243.000us             2
#        aten::empty_strided         0.25%      72.001us         1.05%     309.327us     103.109us     327.000us         1.74%     327.000us     109.000us             3
#                aten::copy_         0.07%      21.694us         0.39%     115.174us      57.587us     121.000us         0.65%     121.000us      60.500us             2
#                aten::zeros         0.10%      28.272us         0.34%     100.070us     100.070us      30.000us         0.16%     102.000us     102.000us             1
# --------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 29.356ms
# Self CUDA time total: 18.743ms
# <ipython-input-5-5f21cbf2019f>:26: FutureWarning: The attribute `use_cuda` will be deprecated soon, please use ``use_device = 'cuda'`` instead.
#   with torch.autograd.profiler.profile(use_cuda=True) as prof:
# attn values sanity check: True

# %% [markdown]
# ### Our Code
# Our new code for LLM benchmarking. We will start with GPT-2. Note with newer models attention might get weird so we may want to avoid them for now (e.g., those with RoPE).
#
# We will start by defining a custom operator in PyTorch, [as explained in the docs](https://pytorch.org/tutorials/advanced/cpp_custom_ops.html#cpp-custom-ops-tutorial) and [examples](https://github.com/pytorch/extension-cpp).

# %% [markdown]
# First, we'll define a `setup.py` based on [the PyTorch `extension-cpp` examples](https://github.com/pytorch/extension-cpp/blob/master/setup.py). Then, we will define an operator within our `flash.cu` code. We first define a namespace, `minimal_attn`, then implement `mha_forward` as an operator (this is what we wrote in Cuda & c++). Below we will test the operator. Note that the dir structure must be as follows:
#
# ```
# .
# ├── minimal_attn/
# │   └── csrc/
# │       ├── your_cpp_code.cpp
# │       └── cuda/
# │           └── flash.cu
# ├── setup.py
# ```
#
# With this, we can `pip install --no-build-isolation -e .` to get our `minimal_attn` extension.

# %%
# !export TORCH_CUDA_ARCH_LIST="7.5;8.0;8.6"
# !pip install --no-build-isolation -e .
# Out:
# WARNING: The directory '/ib-scratch/chenguang02/scratch1/cnicholas/pip_cache' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /opt/conda/lib/python3.12/site-packages (from minimal_attn==0.0.1) (2.5.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch->minimal_attn==0.0.1) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.12/site-packages (from torch->minimal_attn==0.0.1) (4.12.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch->minimal_attn==0.0.1) (70.0.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.12/site-packages (from torch->minimal_attn==0.0.1) (1.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch->minimal_attn==0.0.1) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch->minimal_attn==0.0.1) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch->minimal_attn==0.0.1) (2024.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy==1.13.1->torch->minimal_attn==0.0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch->minimal_attn==0.0.1) (3.0.2)
# Installing collected packages: minimal_attn
#   Attempting uninstall: minimal_attn
#     Found existing installation: minimal_attn 0.0.1
#     Uninstalling minimal_attn-0.0.1:
#       Successfully uninstalled minimal_attn-0.0.1
#   Running setup.py develop for minimal_attn
#     error: subprocess-exited-with-error
#
#     × python setup.py develop did not run successfully.
#     │ exit code: 1
#     ╰─> [1311 lines of output]
#         running develop
#         /opt/conda/lib/python3.12/site-packages/setuptools/command/develop.py:42: EasyInstallDeprecationWarning: easy_install command is deprecated.
#         !!
#
#                 ********************************************************************************
#                 Please avoid running ``setup.py`` and ``easy_install``.
#                 Instead, use pypa/build, pypa/installer or other
#                 standards-based tools.
#
#                 See https://github.com/pypa/setuptools/issues/917 for details.
#                 ********************************************************************************
#
#         !!
#           easy_install.initialize_options(self)
#         /opt/conda/lib/python3.12/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#         !!
#
#                 ********************************************************************************
#                 Please avoid running ``setup.py`` directly.
#                 Instead, use pypa/build, pypa/installer or other
#                 standards-based tools.
#
#                 See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#                 ********************************************************************************
#
#         !!
#           self.initialize_options()
#         running egg_info
#         writing minimal_attn.egg-info/PKG-INFO
#         writing dependency_links to minimal_attn.egg-info/dependency_links.txt
#         writing requirements to minimal_attn.egg-info/requires.txt
#         writing top-level names to minimal_attn.egg-info/top_level.txt
#         reading manifest file 'minimal_attn.egg-info/SOURCES.txt'
#         writing manifest file 'minimal_attn.egg-info/SOURCES.txt'
#         running build_ext
#         /opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.4). Most likely this shouldn't be a problem.
#           warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
#         /opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no g++ version bounds defined for CUDA version 12.5
#           warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
#         building 'minimal_attn._C' extension
#         /opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
#         If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#           warnings.warn(
#         Emitting ninja build file /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/build/temp.linux-x86_64-cpython-312/build.ninja...
#         Compiling objects...
#         Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
#         [1/1] c++ -MMD -MF /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/build/temp.linux-x86_64-cpython-312/minimal_attn/csrc/default.o.d -pthread -B /opt/conda/compiler_compat -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC -I/opt/conda/lib/python3.12/site-packages/torch/include -I/opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -I/opt/conda/lib/python3.12/site-packages/torch/include/TH -I/opt/conda/lib/python3.12/site-packages/torch/include/THC -I/usr/local/cuda/include -I/opt/conda/include/python3.12 -c -c /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/minimal_attn/csrc/default.cpp -o /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/build/temp.linux-x86_64-cpython-312/minimal_attn/csrc/default.o -O3 -fdiagnostics-color=always -DPy_LIMITED_API=0x03090000 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
#         FAILED: /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/build/temp.linux-x86_64-cpython-312/minimal_attn/csrc/default.o
#         c++ -MMD -MF /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/build/temp.linux-x86_64-cpython-312/minimal_attn/csrc/default.o.d -pthread -B /opt/conda/compiler_compat -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC -I/opt/conda/lib/python3.12/site-packages/torch/include -I/opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include -I/opt/conda/lib/python3.12/site-packages/torch/include/TH -I/opt/conda/lib/python3.12/site-packages/torch/include/THC -I/usr/local/cuda/include -I/opt/conda/include/python3.12 -c -c /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/minimal_attn/csrc/default.cpp -o /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/build/temp.linux-x86_64-cpython-312/minimal_attn/csrc/default.o -O3 -fdiagnostics-color=always -DPy_LIMITED_API=0x03090000 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
#         In file included from /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:13,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/type_caster_base.h:12,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:15,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/attr.h:14,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/class.h:12,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pybind11.h:13,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/Exceptions.h:12,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/python.h:11,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/extension.h:9,
#                          from /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/minimal_attn/csrc/default.cpp:8:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:107:35: error: expected ‘)’ before ‘*’ token
#           107 |     explicit buffer_info(Py_buffer *view, bool ownview = true)
#               |                         ~         ^~
#               |                                   )
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:113:54: error: expected unqualified-id before ‘,’ token
#           113 |               {view->shape, view->shape + view->ndim},
#               |                                                      ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:119:78: error: expected unqualified-id before ‘,’ token
#           119 |                   : detail::c_strides({view->shape, view->shape + view->ndim}, view->itemsize),
#               |                                                                              ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:153:5: error: ‘Py_buffer’ does not name a type
#           153 |     Py_buffer *view() const { return m_view; }
#               |     ^~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:154:5: error: ‘Py_buffer’ does not name a type
#           154 |     Py_buffer *&view() { return m_view; }
#               |     ^~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:181:5: error: ‘Py_buffer’ does not name a type
#           181 |     Py_buffer *m_view = nullptr;
#               |     ^~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h: In member function ‘pybind11::buffer_info& pybind11::buffer_info::operator=(pybind11::buffer_info&&)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:140:19: error: ‘m_view’ was not declared in this scope
#           140 |         std::swap(m_view, rhs.m_view);
#               |                   ^~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:140:31: error: ‘struct pybind11::buffer_info’ has no member named ‘m_view’
#           140 |         std::swap(m_view, rhs.m_view);
#               |                               ^~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h: In destructor ‘pybind11::buffer_info::~buffer_info()’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:147:13: error: ‘m_view’ was not declared in this scope
#           147 |         if (m_view && ownview) {
#               |             ^~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:148:13: error: ‘PyBuffer_Release’ was not declared in this scope
#           148 |             PyBuffer_Release(m_view);
#               |             ^~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/buffer_info.h:149:20: error: type ‘<type error>’ argument given to ‘delete’, expected pointer
#           149 |             delete m_view;
#               |                    ^~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In function ‘const char* pybind11::detail::obj_class_name(PyObject*)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:489:53: error: invalid use of incomplete type ‘PyTypeObject’ {aka ‘struct _typeobject’}
#           489 |         return reinterpret_cast<PyTypeObject *>(obj)->tp_name;
#               |                                                     ^~
#         In file included from /opt/conda/include/python3.12/Python.h:42,
#                          from /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/minimal_attn/csrc/default.cpp:1:
#         /opt/conda/include/python3.12/pytypedefs.h:20:16: note: forward declaration of ‘PyTypeObject’ {aka ‘struct _typeobject’}
#            20 | typedef struct _typeobject PyTypeObject;
#               |                ^~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:491:24: error: invalid use of incomplete type ‘PyTypeObject’ {aka ‘struct _typeobject’}
#           491 |     return Py_TYPE(obj)->tp_name;
#               |                        ^~
#         /opt/conda/include/python3.12/pytypedefs.h:20:16: note: forward declaration of ‘PyTypeObject’ {aka ‘struct _typeobject’}
#            20 | typedef struct _typeobject PyTypeObject;
#               |                ^~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In member function ‘std::string pybind11::detail::error_fetch_and_normalize::format_value_and_trace() const’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:615:42: error: ‘PyList_GET_ITEM’ was not declared in this scope; did you mean ‘PyList_GetItem’?
#           615 |                         PyObject *note = PyList_GET_ITEM(notes.ptr(), i);
#               |                                          ^~~~~~~~~~~~~~~
#               |                                          PyList_GetItem
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:647:41: error: ‘PyTracebackObject’ does not name a type; did you mean ‘PyTraceBack_Check’?
#           647 |             auto *tb = reinterpret_cast<PyTracebackObject *>(m_trace.ptr());
#               |                                         ^~~~~~~~~~~~~~~~~
#               |                                         PyTraceBack_Check
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:647:59: error: expected ‘>’ before ‘*’ token
#           647 |             auto *tb = reinterpret_cast<PyTracebackObject *>(m_trace.ptr());
#               |                                                           ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:647:59: error: expected ‘(’ before ‘*’ token
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:647:60: error: expected primary-expression before ‘>’ token
#           647 |             auto *tb = reinterpret_cast<PyTracebackObject *>(m_trace.ptr());
#               |                                                            ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:647:76: error: expected ‘)’ before ‘;’ token
#           647 |             auto *tb = reinterpret_cast<PyTracebackObject *>(m_trace.ptr());
#               |                                                                            ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:666:40: error: invalid use of incomplete type ‘PyCodeObject’ {aka ‘struct PyCodeObject’}
#           666 |                 result += handle(f_code->co_filename).cast<std::string>();
#               |                                        ^~
#         /opt/conda/include/python3.12/pytypedefs.h:21:16: note: forward declaration of ‘PyCodeObject’ {aka ‘struct PyCodeObject’}
#            21 | typedef struct PyCodeObject PyCodeObject;
#               |                ^~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:666:71: error: expected primary-expression before ‘>’ token
#           666 |                 result += handle(f_code->co_filename).cast<std::string>();
#               |                                                                       ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:666:73: error: expected primary-expression before ‘)’ token
#           666 |                 result += handle(f_code->co_filename).cast<std::string>();
#               |                                                                         ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:670:40: error: invalid use of incomplete type ‘PyCodeObject’ {aka ‘struct PyCodeObject’}
#           670 |                 result += handle(f_code->co_name).cast<std::string>();
#               |                                        ^~
#         /opt/conda/include/python3.12/pytypedefs.h:21:16: note: forward declaration of ‘PyCodeObject’ {aka ‘struct PyCodeObject’}
#            21 | typedef struct PyCodeObject PyCodeObject;
#               |                ^~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:670:67: error: expected primary-expression before ‘>’ token
#           670 |                 result += handle(f_code->co_name).cast<std::string>();
#               |                                                                   ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:670:69: error: expected primary-expression before ‘)’ token
#           670 |                 result += handle(f_code->co_name).cast<std::string>();
#               |                                                                     ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:674:33: error: ‘PyFrame_GetBack’ was not declared in this scope; did you mean ‘PyFrame_GetCode’?
#           674 |                 auto *b_frame = PyFrame_GetBack(frame);
#               |                                 ^~~~~~~~~~~~~~~
#               |                                 PyFrame_GetCode
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In function ‘pybind11::handle pybind11::detail::get_function(pybind11::handle)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:947:13: error: ‘PyInstanceMethod_Check’ was not declared in this scope
#           947 |         if (PyInstanceMethod_Check(value.ptr())) {
#               |             ^~~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:948:21: error: ‘PyInstanceMethod_GET_FUNCTION’ was not declared in this scope
#           948 |             value = PyInstanceMethod_GET_FUNCTION(value.ptr());
#               |                     ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:949:20: error: ‘PyMethod_Check’ was not declared in this scope; did you mean ‘PySet_Check’?
#           949 |         } else if (PyMethod_Check(value.ptr())) {
#               |                    ^~~~~~~~~~~~~~
#               |                    PySet_Check
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:950:21: error: ‘PyMethod_GET_FUNCTION’ was not declared in this scope
#           950 |             value = PyMethod_GET_FUNCTION(value.ptr());
#               |                     ^~~~~~~~~~~~~~~~~~~~~
#         In file included from /opt/conda/include/python3.12/Python.h:100:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In constructor ‘pybind11::detail::iterator_policies::sequence_fast_readonly::sequence_fast_readonly(pybind11::handle, pybind11::ssize_t)’:
#         /opt/conda/include/python3.12/abstract.h:756:27: error: ‘PyListObject’ was not declared in this scope; did you mean ‘PyLongObject’?
#           756 |     (PyList_Check(sf) ? ((PyListObject *)(sf))->ob_item \
#               |                           ^~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1261:57: note: in expansion of macro ‘PySequence_Fast_ITEMS’
#          1261 |     sequence_fast_readonly(handle obj, ssize_t n) : ptr(PySequence_Fast_ITEMS(obj.ptr()) + n) {}
#               |                                                         ^~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/include/python3.12/abstract.h:756:41: error: expected primary-expression before ‘)’ token
#           756 |     (PyList_Check(sf) ? ((PyListObject *)(sf))->ob_item \
#               |                                         ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1261:57: note: in expansion of macro ‘PySequence_Fast_ITEMS’
#          1261 |     sequence_fast_readonly(handle obj, ssize_t n) : ptr(PySequence_Fast_ITEMS(obj.ptr()) + n) {}
#               |                                                         ^~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/include/python3.12/abstract.h:757:27: error: ‘PyTupleObject’ was not declared in this scope; did you mean ‘PyTypeObject’?
#           757 |                       : ((PyTupleObject *)(sf))->ob_item)
#               |                           ^~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1261:57: note: in expansion of macro ‘PySequence_Fast_ITEMS’
#          1261 |     sequence_fast_readonly(handle obj, ssize_t n) : ptr(PySequence_Fast_ITEMS(obj.ptr()) + n) {}
#               |                                                         ^~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/include/python3.12/abstract.h:757:42: error: expected primary-expression before ‘)’ token
#           757 |                       : ((PyTupleObject *)(sf))->ob_item)
#               |                                          ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1261:57: note: in expansion of macro ‘PySequence_Fast_ITEMS’
#          1261 |     sequence_fast_readonly(handle obj, ssize_t n) : ptr(PySequence_Fast_ITEMS(obj.ptr()) + n) {}
#               |                                                         ^~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In function ‘bool pybind11::detail::PyStaticMethod_Check(PyObject*)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1359:71: error: ‘PyStaticMethod_Type’ was not declared in this scope; did you mean ‘PyStaticMethod_Check’?
#          1359 | inline bool PyStaticMethod_Check(PyObject *o) { return o->ob_type == &PyStaticMethod_Type; }
#               |                                                                       ^~~~~~~~~~~~~~~~~~~
#               |                                                                       PyStaticMethod_Check
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In member function ‘pybind11::bytearray::operator std::string() const’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1777:24: error: ‘PyByteArray_AS_STRING’ was not declared in this scope; did you mean ‘PyByteArray_AsString’?
#          1777 |         char *buffer = PyByteArray_AS_STRING(m_ptr);
#               |                        ^~~~~~~~~~~~~~~~~~~~~
#               |                        PyByteArray_AsString
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1778:24: error: ‘PyByteArray_GET_SIZE’ was not declared in this scope; did you mean ‘PyByteArray_Size’?
#          1778 |         ssize_t size = PyByteArray_GET_SIZE(m_ptr);
#               |                        ^~~~~~~~~~~~~~~~~~~~
#               |                        PyByteArray_Size
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In member function ‘pybind11::detail::tuple_iterator pybind11::tuple::end() const’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2098:57: error: ‘PyTuple_GET_SIZE’ was not declared in this scope; did you mean ‘PyTuple_GetSlice’?
#          2098 |     detail::tuple_iterator end() const { return {*this, PyTuple_GET_SIZE(m_ptr)}; }
#               |                                                         ^~~~~~~~~~~~~~~~
#               |                                                         PyTuple_GetSlice
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2098:80: error: could not convert ‘{(*(const pybind11::tuple*)this), <expression error>}’ from ‘<brace-enclosed initializer list>’ to ‘pybind11::detail::tuple_iterator’ {aka ‘pybind11::detail::generic_iterator<pybind11::detail::iterator_policies::sequence_fast_readonly>’}
#          2098 |     detail::tuple_iterator end() const { return {*this, PyTuple_GET_SIZE(m_ptr)}; }
#               |                                                                                ^
#               |                                                                                |
#               |                                                                                <brace-enclosed initializer list>
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In member function ‘pybind11::detail::list_iterator pybind11::list::end() const’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2187:56: error: ‘PyList_GET_SIZE’ was not declared in this scope; did you mean ‘Py_SET_SIZE’?
#          2187 |     detail::list_iterator end() const { return {*this, PyList_GET_SIZE(m_ptr)}; }
#               |                                                        ^~~~~~~~~~~~~~~
#               |                                                        Py_SET_SIZE
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2187:78: error: could not convert ‘{(*(const pybind11::list*)this), <expression error>}’ from ‘<brace-enclosed initializer list>’ to ‘pybind11::detail::list_iterator’ {aka ‘pybind11::detail::generic_iterator<pybind11::detail::iterator_policies::sequence_fast_readonly>’}
#          2187 |     detail::list_iterator end() const { return {*this, PyList_GET_SIZE(m_ptr)}; }
#               |                                                                              ^
#               |                                                                              |
#               |                                                                              <brace-enclosed initializer list>
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In constructor ‘pybind11::staticmethod::staticmethod(const pybind11::object&)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2269:77: error: ‘PyStaticMethod_New’ was not declared in this scope; did you mean ‘PyCMethod_New’?
#          2269 |     PYBIND11_OBJECT_CVT(staticmethod, object, detail::PyStaticMethod_Check, PyStaticMethod_New)
#               |                                                                             ^~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1414:50: note: in definition of macro ‘PYBIND11_OBJECT_CVT’
#          1414 |         : Parent(check_(o) ? o.inc_ref().ptr() : ConvertFun(o.ptr()), stolen_t{}) {               \
#               |                                                  ^~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In constructor ‘pybind11::staticmethod::staticmethod(pybind11::object&&)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2269:77: error: ‘PyStaticMethod_New’ was not declared in this scope; did you mean ‘PyCMethod_New’?
#          2269 |     PYBIND11_OBJECT_CVT(staticmethod, object, detail::PyStaticMethod_Check, PyStaticMethod_New)
#               |                                                                             ^~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1419:63: note: in definition of macro ‘PYBIND11_OBJECT_CVT’
#          1419 |     Name(object &&o) : Parent(check_(o) ? o.release().ptr() : ConvertFun(o.ptr()), stolen_t{}) {  \
#               |                                                               ^~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In member function ‘bool pybind11::buffer::check() const’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2274:45: error: ‘PyObject_CheckBuffer’ was not declared in this scope; did you mean ‘PyObject_CheckReadBuffer’?
#          2274 |     PYBIND11_OBJECT_DEFAULT(buffer, object, PyObject_CheckBuffer)
#               |                                             ^~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1404:54: note: in definition of macro ‘PYBIND11_OBJECT_COMMON’
#          1404 |     bool check() const { return m_ptr != nullptr && (CheckFun(m_ptr) != 0); }                     \
#               |                                                      ^~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1448:5: note: in expansion of macro ‘PYBIND11_OBJECT’
#          1448 |     PYBIND11_OBJECT(Name, Parent, CheckFun)                                                       \
#               |     ^~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2274:5: note: in expansion of macro ‘PYBIND11_OBJECT_DEFAULT’
#          2274 |     PYBIND11_OBJECT_DEFAULT(buffer, object, PyObject_CheckBuffer)
#               |     ^~~~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In static member function ‘static bool pybind11::buffer::check_(pybind11::handle)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2274:45: error: ‘PyObject_CheckBuffer’ was not declared in this scope; did you mean ‘PyObject_CheckReadBuffer’?
#          2274 |     PYBIND11_OBJECT_DEFAULT(buffer, object, PyObject_CheckBuffer)
#               |                                             ^~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1405:65: note: in definition of macro ‘PYBIND11_OBJECT_COMMON’
#          1405 |     static bool check_(handle h) { return h.ptr() != nullptr && CheckFun(h.ptr()); }              \
#               |                                                                 ^~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1448:5: note: in expansion of macro ‘PYBIND11_OBJECT’
#          1448 |     PYBIND11_OBJECT(Name, Parent, CheckFun)                                                       \
#               |     ^~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2274:5: note: in expansion of macro ‘PYBIND11_OBJECT_DEFAULT’
#          2274 |     PYBIND11_OBJECT_DEFAULT(buffer, object, PyObject_CheckBuffer)
#               |     ^~~~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In member function ‘pybind11::buffer_info pybind11::buffer::request(bool) const’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2277:21: error: ‘PyBUF_STRIDES’ was not declared in this scope
#          2277 |         int flags = PyBUF_STRIDES | PyBUF_FORMAT;
#               |                     ^~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2277:37: error: ‘PyBUF_FORMAT’ was not declared in this scope
#          2277 |         int flags = PyBUF_STRIDES | PyBUF_FORMAT;
#               |                                     ^~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2279:22: error: ‘PyBUF_WRITABLE’ was not declared in this scope
#          2279 |             flags |= PyBUF_WRITABLE;
#               |                      ^~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2281:26: error: expected type-specifier before ‘Py_buffer’
#          2281 |         auto *view = new Py_buffer();
#               |                          ^~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2282:13: error: ‘PyObject_GetBuffer’ was not declared in this scope; did you mean ‘PyObject_GetIter’?
#          2282 |         if (PyObject_GetBuffer(m_ptr, view, flags) != 0) {
#               |             ^~~~~~~~~~~~~~~~~~
#               |             PyObject_GetIter
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2283:20: error: type ‘<type error>’ argument given to ‘delete’, expected pointer
#          2283 |             delete view;
#               |                    ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In constructor ‘pybind11::memoryview::memoryview(const pybind11::buffer_info&)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2304:19: error: ‘const struct pybind11::buffer_info’ has no member named ‘view’
#          2304 |         if (!info.view()) {
#               |                   ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2308:23: error: ‘const struct pybind11::buffer_info’ has no member named ‘view’
#          2308 |         m_ptr = (info.view()->obj) ? PyMemoryView_FromObject(info.view()->obj)
#               |                       ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2308:67: error: ‘const struct pybind11::buffer_info’ has no member named ‘view’
#          2308 |         m_ptr = (info.view()->obj) ? PyMemoryView_FromObject(info.view()->obj)
#               |                                                                   ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2309:67: error: ‘const struct pybind11::buffer_info’ has no member named ‘view’
#          2309 |                                    : PyMemoryView_FromBuffer(info.view());
#               |                                                                   ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2309:38: error: ‘PyMemoryView_FromBuffer’ was not declared in this scope; did you mean ‘PyMemoryView_FromObject’?
#          2309 |                                    : PyMemoryView_FromBuffer(info.view());
#               |                                      ^~~~~~~~~~~~~~~~~~~~~~~
#               |                                      PyMemoryView_FromObject
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In static member function ‘static pybind11::memoryview pybind11::memoryview::from_memory(void*, pybind11::ssize_t, bool)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2390:63: error: ‘PyBUF_READ’ was not declared in this scope
#          2390 |             reinterpret_cast<char *>(mem), size, (readonly) ? PyBUF_READ : PyBUF_WRITE);
#               |                                                               ^~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2390:76: error: ‘PyBUF_WRITE’ was not declared in this scope
#          2390 |             reinterpret_cast<char *>(mem), size, (readonly) ? PyBUF_READ : PyBUF_WRITE);
#               |                                                                            ^~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In static member function ‘static pybind11::memoryview pybind11::memoryview::from_buffer(void*, pybind11::ssize_t, const char*, pybind11::detail::any_container<long int>, pybind11::detail::any_container<long int>, bool)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2423:5: error: ‘Py_buffer’ was not declared in this scope; did you mean ‘buffer’?
#          2423 |     Py_buffer view;
#               |     ^~~~~~~~~
#               |     buffer
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2424:5: error: ‘view’ was not declared in this scope
#          2424 |     view.buf = ptr;
#               |     ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2424:5: note: suggested alternatives:
#         In file included from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/jit/ir/ir.h:18,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/jit/api/function_impl.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/jit/api/method.h:7,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/jit/api/object.h:5,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/jit/api/module.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/serialize/input-archive.h:5,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/serialize/archive.h:3,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/samplers/serialize.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/samplers.h:8,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/datasets/chunk.h:6,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/datasets.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/all.h:9,
#                          from /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/minimal_attn/csrc/default.cpp:3:
#         /opt/conda/lib/python3.12/site-packages/torch/include/ATen/core/aten_interned_strings.h:1563:9: note:   ‘c10::aten::view’
#          1563 | _(aten, view) \
#               |         ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/ATen/core/interned_strings.h:351:35: note: in definition of macro ‘DEFINE_SYMBOL’
#           351 |   namespace ns { constexpr Symbol s(static_cast<unique_t>(_keys::ns##_##s)); }
#               |                                   ^
#         /opt/conda/lib/python3.12/site-packages/torch/include/ATen/core/interned_strings.h:232:3: note: in expansion of macro ‘FORALL_ATEN_BASE_SYMBOLS’
#           232 |   FORALL_ATEN_BASE_SYMBOLS(_)        \
#               |   ^~~~~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/ATen/core/interned_strings.h:352:1: note: in expansion of macro ‘FORALL_NS_SYMBOLS’
#           352 | FORALL_NS_SYMBOLS(DEFINE_SYMBOL)
#               | ^~~~~~~~~~~~~~~~~
#         In file included from /opt/conda/lib/python3.12/site-packages/torch/include/ATen/Operators.h:1326,
#                          from /home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/minimal_attn/csrc/default.cpp:2:
#         /opt/conda/lib/python3.12/site-packages/torch/include/ATen/ops/view_ops.h:17:18: note:   ‘at::_ops::view’
#            17 | struct TORCH_API view {
#               |                  ^~~~
#         In file included from /opt/conda/lib/python3.12/site-packages/torch/include/ATen/Functions.h:1374,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/ATen/ExpandUtils.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/input_metadata.h:3,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/function.h:7,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/autograd/custom_function.h:7,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/autograd.h:5,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/all.h:7:
#         /opt/conda/lib/python3.12/site-packages/torch/include/ATen/ops/view.h:34:14: note:   ‘at::symint::view’
#            34 |   at::Tensor view(const at::Tensor & self, c10::SymIntArrayRef size) {
#               |              ^~~~
#         In file included from /opt/conda/lib/python3.12/site-packages/torch/include/ATen/NativeFunctions.h:1328,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/ATen/TensorIndexing.h:13,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/ATen/ATen.h:18,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:4,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                          from /opt/conda/lib/python3.12/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3:
#         /opt/conda/lib/python3.12/site-packages/torch/include/ATen/ops/view_native.h:19:22: note:   ‘at::native::view’
#            19 | TORCH_API at::Tensor view(const at::Tensor & self, at::IntArrayRef size);
#               |                      ^~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2435:21: error: ‘PyMemoryView_FromBuffer’ was not declared in this scope; did you mean ‘PyMemoryView_FromObject’?
#          2435 |     PyObject *obj = PyMemoryView_FromBuffer(&view);
#               |                     ^~~~~~~~~~~~~~~~~~~~~~~
#               |                     PyMemoryView_FromObject
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h: In function ‘pybind11::size_t pybind11::len_hint(handle)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2459:22: error: ‘PyObject_LengthHint’ was not declared in this scope; did you mean ‘PyObject_Length’?
#          2459 |     ssize_t result = PyObject_LengthHint(h.ptr(), 0);
#               |                      ^~~~~~~~~~~~~~~~~~~
#               |                      PyObject_Length
#         In file included from /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/type_caster_base.h:16:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/internals.h: At global scope:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/internals.h:207:27: error: field ‘tstate’ has incomplete type ‘Py_tss_t’ {aka ‘_Py_tss_t’}
#           207 |     PYBIND11_TLS_KEY_INIT(tstate)
#               |                           ^~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/internals.h:82:26: note: in definition of macro ‘PYBIND11_TLS_KEY_INIT’
#            82 |                 Py_tss_t var                                                                      \
#               |                          ^~~
#         In file included from /opt/conda/include/python3.12/Python.h:89:
#         /opt/conda/include/python3.12/pythread.h:113:16: note: forward declaration of ‘Py_tss_t’ {aka ‘struct _Py_tss_t’}
#           113 | typedef struct _Py_tss_t Py_tss_t;  /* opaque */
#               |                ^~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/internals.h:209:27: error: field ‘loader_life_support_tls_key’ has incomplete type ‘Py_tss_t’ {aka ‘_Py_tss_t’}
#           209 |     PYBIND11_TLS_KEY_INIT(loader_life_support_tls_key)
#               |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/internals.h:82:26: note: in definition of macro ‘PYBIND11_TLS_KEY_INIT’
#            82 |                 Py_tss_t var                                                                      \
#               |                          ^~~
#         /opt/conda/include/python3.12/pythread.h:113:16: note: forward declaration of ‘Py_tss_t’ {aka ‘struct _Py_tss_t’}
#           113 | typedef struct _Py_tss_t Py_tss_t;  /* opaque */
#               |                ^~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/internals.h: In function ‘pybind11::detail::internals& pybind11::detail::get_internals()’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/internals.h:555:39: error: invalid use of incomplete type ‘PyThreadState’ {aka ‘struct _ts’}
#           555 |         internals_ptr->istate = tstate->interp;
#               |                                       ^~
#         /opt/conda/include/python3.12/pytypedefs.h:24:16: note: forward declaration of ‘PyThreadState’ {aka ‘struct _ts’}
#            24 | typedef struct _ts PyThreadState;
#               |                ^~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/type_caster_base.h: In function ‘void pybind11::detail::all_type_info_populate(PyTypeObject*, std::vector<type_info*>&)’:
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/type_caster_base.h:114:53: error: invalid use of incomplete type ‘PyTypeObject’ {aka ‘struct _typeobject’}
#           114 |     for (handle parent : reinterpret_borrow<tuple>(t->tp_bases)) {
#               |                                                     ^~
#         /opt/conda/include/python3.12/pytypedefs.h:20:16: note: forward declaration of ‘PyTypeObject’ {aka ‘struct _typeobject’}
#            20 | typedef struct _typeobject PyTypeObject;
#               |                ^~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/type_caster_base.h:148:24: error: invalid use of incomplete type ‘struct _typeobject’
#           148 |         } else if (type->tp_bases) {
#               |                        ^~
#         /opt/conda/include/python3.12/pytypedefs.h:20:16: note: forward declaration of ‘struct _typeobject’
#            20 | typedef struct _typeobject PyTypeObject;
#               |                ^~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/type_caster_base.h:158:64: error: invalid use of incomplete type ‘struct _typeobject’
#           158 |             for (handle parent : reinterpret_borrow<tuple>(type->tp_bases)) {
#               |                                                                ^~
#         /opt/conda/include/python3.12/pytypedefs.h:20:16: note: forward declaration of ‘struct _typeobject’
#            20 | typedef struct _typeobject PyTypeObject;
#               |                ^~~~~~~~~~~
#         /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/detail/type_caster_base.h: In function ‘PyThreadState* pybind11::detail::get_thread_state_unchecked()’:
# ...
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1635:30:   required from ‘pybind11::str pybind11::str::format(Args&& ...) const [with Args = {const pybind11::handle&}]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pybind11.h:1158:59:   required from here
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1412:25: error: ‘PyTuple_SET_ITEM’ was not declared in this scope; did you mean ‘PyTuple_SetItem’?
#      1412 |         PyTuple_SET_ITEM(result.ptr(), counter++, arg_value.release().ptr());
#           |         ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           |         PyTuple_SetItem
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h: In instantiation of ‘pybind11::tuple pybind11::make_tuple(Args&& ...) [with return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {const char* const&}]’:
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1644:46:   required from ‘pybind11::detail::simple_collector<policy>::simple_collector(Ts&& ...) [with Ts = {const char* const&}; pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1797:12:   required from ‘pybind11::detail::simple_collector<policy> pybind11::detail::collect_arguments(Args&& ...) [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {const char* const&}; <template-parameter-1-3> = void]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1823:45:   required from ‘pybind11::object pybind11::detail::object_api<Derived>::operator()(Args&& ...) const [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {const char* const&}; Derived = pybind11::detail::accessor<pybind11::detail::accessor_policies::str_attr>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2526:32:   required from ‘bool pybind11::detail::object_api<Derived>::contains(T&&) const [with T = const char* const&; Derived = pybind11::detail::accessor<pybind11::detail::accessor_policies::str_attr>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pybind11.h:1398:51:   required from here
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1412:25: error: ‘PyTuple_SET_ITEM’ was not declared in this scope; did you mean ‘PyTuple_SetItem’?
#      1412 |         PyTuple_SET_ITEM(result.ptr(), counter++, arg_value.release().ptr());
#           |         ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           |         PyTuple_SetItem
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h: In instantiation of ‘pybind11::tuple pybind11::make_tuple(Args&& ...) [with return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {const char (&)[9]}]’:
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1644:46:   required from ‘pybind11::detail::simple_collector<policy>::simple_collector(Ts&& ...) [with Ts = {const char (&)[9]}; pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1797:12:   required from ‘pybind11::detail::simple_collector<policy> pybind11::detail::collect_arguments(Args&& ...) [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {const char (&)[9]}; <template-parameter-1-3> = void]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1823:45:   required from ‘pybind11::object pybind11::detail::object_api<Derived>::operator()(Args&& ...) const [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {const char (&)[9]}; Derived = pybind11::detail::accessor<pybind11::detail::accessor_policies::str_attr>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:2526:32:   required from ‘bool pybind11::detail::object_api<Derived>::contains(T&&) const [with T = const char (&)[9]; Derived = pybind11::detail::accessor<pybind11::detail::accessor_policies::str_attr>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pybind11.h:1557:76:   required from here
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1412:25: error: ‘PyTuple_SET_ITEM’ was not declared in this scope; did you mean ‘PyTuple_SetItem’?
#      1412 |         PyTuple_SET_ITEM(result.ptr(), counter++, arg_value.release().ptr());
#           |         ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           |         PyTuple_SetItem
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h: In instantiation of ‘pybind11::tuple pybind11::make_tuple(Args&& ...) [with return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {object, str, int_}]’:
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1644:46:   required from ‘pybind11::detail::simple_collector<policy>::simple_collector(Ts&& ...) [with Ts = {pybind11::object, pybind11::str, pybind11::int_}; pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1797:12:   required from ‘pybind11::detail::simple_collector<policy> pybind11::detail::collect_arguments(Args&& ...) [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {pybind11::object, pybind11::str, pybind11::int_}; <template-parameter-1-3> = void]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1823:45:   required from ‘pybind11::object pybind11::detail::object_api<Derived>::operator()(Args&& ...) const [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {pybind11::object, pybind11::str, pybind11::int_}; Derived = pybind11::detail::accessor<pybind11::detail::accessor_policies::str_attr>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1635:30:   required from ‘pybind11::str pybind11::str::format(Args&& ...) const [with Args = {pybind11::object, pybind11::str, pybind11::int_}]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pybind11.h:2062:28:   required from here
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1412:25: error: ‘PyTuple_SET_ITEM’ was not declared in this scope; did you mean ‘PyTuple_SetItem’?
#      1412 |         PyTuple_SET_ITEM(result.ptr(), counter++, arg_value.release().ptr());
#           |         ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           |         PyTuple_SetItem
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h: In instantiation of ‘pybind11::tuple pybind11::make_tuple(Args&& ...) [with return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {object, str}]’:
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1644:46:   required from ‘pybind11::detail::simple_collector<policy>::simple_collector(Ts&& ...) [with Ts = {pybind11::object, pybind11::str}; pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1797:12:   required from ‘pybind11::detail::simple_collector<policy> pybind11::detail::collect_arguments(Args&& ...) [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {pybind11::object, pybind11::str}; <template-parameter-1-3> = void]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1823:45:   required from ‘pybind11::object pybind11::detail::object_api<Derived>::operator()(Args&& ...) const [with pybind11::return_value_policy policy = pybind11::return_value_policy::automatic_reference; Args = {pybind11::object, pybind11::str}; Derived = pybind11::detail::accessor<pybind11::detail::accessor_policies::str_attr>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pytypes.h:1635:30:   required from ‘pybind11::str pybind11::str::format(Args&& ...) const [with Args = {pybind11::object, pybind11::str}]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/pybind11.h:2072:53:   required from here
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1412:25: error: ‘PyTuple_SET_ITEM’ was not declared in this scope; did you mean ‘PyTuple_SetItem’?
#      1412 |         PyTuple_SET_ITEM(result.ptr(), counter++, arg_value.release().ptr());
#           |         ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#           |         PyTuple_SetItem
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h: In instantiation of ‘bool pybind11::detail::string_caster<StringType, IsView>::load(pybind11::handle, bool) [with StringType = std::basic_string_view<char>; bool IsView = true]’:
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1149:19:   required from ‘pybind11::detail::type_caster<T, SFINAE>& pybind11::detail::load_type(type_caster<T, SFINAE>&, const pybind11::handle&) [with T = std::basic_string_view<char>; SFINAE = void]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1168:14:   required from ‘pybind11::detail::make_caster<T> pybind11::detail::load_type(const pybind11::handle&) [with T = std::basic_string_view<char>; make_caster<T> = type_caster<std::basic_string_view<char>, void>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1184:35:   required from ‘T pybind11::cast(const handle&) [with T = std::basic_string_view<char>; typename std::enable_if<((! std::is_base_of<detail::pyobject_tag, typename std::remove_reference<_Tp>::type>::value) && (! std::is_same<typename detail::remove_cvref<T>::type, _object*>::value)), int>::type <anonymous> = 0]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1283:23:   required from ‘std::enable_if_t<((! std::is_base_of<pybind11::detail::pyobject_tag, typename std::remove_reference<_Tp>::type>::value) && pybind11::detail::move_if_unreferenced<T>::value), T> pybind11::cast(object&&) [with T = std::basic_string_view<char>; std::enable_if_t<((! std::is_base_of<detail::pyobject_tag, typename std::remove_reference<_Tp>::type>::value) && detail::move_if_unreferenced<T>::value), T> = std::basic_string_view<char>; typename std::remove_reference<_Tp>::type = std::basic_string_view<char>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:1305:29:   required from ‘T pybind11::object::cast() && [with T = std::basic_string_view<char>]’
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/stl.h:441:42:   required from here
#     /opt/conda/lib/python3.12/site-packages/torch/include/pybind11/cast.h:411:74: error: ‘PyUnicode_AsUTF8AndSize’ was not declared in this scope; did you mean ‘PyUnicode_AsUTF8String’?
#       411 |                 = reinterpret_cast<const CharT *>(PyUnicode_AsUTF8AndSize(load_src.ptr(), &size));
#           |                                                   ~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
#           |                                                   PyUnicode_AsUTF8String
#     ninja: build stopped: subcommand failed.
#     Traceback (most recent call last):
#       File "/opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 2104, in _run_ninja_build
#         subprocess.run(
#       File "/opt/conda/lib/python3.12/subprocess.py", line 571, in run
#         raise CalledProcessError(retcode, process.args,
#     subprocess.CalledProcessError: Command '['ninja', '-v']' returned non-zero exit status 1.
#
#     The above exception was the direct cause of the following exception:
#
#     Traceback (most recent call last):
#       File "<string>", line 2, in <module>
#       File "<pip-setuptools-caller>", line 34, in <module>
#       File "/home/warehouse/cnicholas/cse4059/final_project/flash-attention-minimal/operator/setup.py", line 77, in <module>
#         setup(
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/__init__.py", line 103, in setup
#         return distutils.core.setup(**attrs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 184, in setup
#         return run_commands(dist)
#                ^^^^^^^^^^^^^^^^^^
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 200, in run_commands
#         dist.run_commands()
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#         self.run_command(cmd)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/dist.py", line 968, in run_command
#         super().run_command(command)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#         cmd_obj.run()
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/command/develop.py", line 36, in run
#         self.install_for_development()
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/command/develop.py", line 113, in install_for_development
#         self.run_command('build_ext')
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/cmd.py", line 316, in run_command
#         self.distribution.run_command(command)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/dist.py", line 968, in run_command
#         super().run_command(command)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#         cmd_obj.run()
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/command/build_ext.py", line 91, in run
#         _build_ext.run(self)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py", line 359, in run
#         self.build_extensions()
#       File "/opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 868, in build_extensions
#         build_ext.build_extensions(self)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py", line 479, in build_extensions
#         self._build_extensions_serial()
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py", line 505, in _build_extensions_serial
#         self.build_extension(ext)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/command/build_ext.py", line 252, in build_extension
#         _build_ext.build_extension(self, ext)
#       File "/opt/conda/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py", line 560, in build_extension
#         objects = self.compiler.compile(
#                   ^^^^^^^^^^^^^^^^^^^^^^
#       File "/opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 681, in unix_wrap_ninja_compile
#         _write_ninja_file_and_compile_objects(
#       File "/opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 1784, in _write_ninja_file_and_compile_objects
#         _run_ninja_build(
#       File "/opt/conda/lib/python3.12/site-packages/torch/utils/cpp_extension.py", line 2120, in _run_ninja_build
#         raise RuntimeError(message) from e
#     RuntimeError: Error compiling objects for extension
#     [end of output]
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import minimal_attn

batch_size = 32
n_head = 12
seq_len = 64
head_embd = 32

def sample_inputs(device, *, requires_grad=False):
    def make_kqv(batch_size, n_head, seq_len, head):
      q = torch.randn(batch_size, n_head, seq_len, head_embd).cuda()
      k = torch.randn(batch_size, n_head, seq_len, head_embd).cuda()
      v = torch.randn(batch_size, n_head, seq_len, head_embd).cuda()
      return q, k, v

    return [
        make_kqv(batch_size, n_head, seq_len, head_embd)
    ]

# Our minimal flash attention needs to be faster than this.
def manual_attn(q, k, v):
    att = (q @ k.transpose(-2, -1) * (1.0 / math.sqrt(k.size(-1))))
    att = F.softmax(att, dim=-1)
    y = att @ v
    return y

device = torch.device('cuda')
samples = sample_inputs(device, requires_grad=True)
samples.extend(sample_inputs(device, requires_grad=False))
for args in samples:
    # Correctness test
    # result = torch.ops.extension_cpp.mymuladd(*args)
    result = torch.ops.minimal_attn.mha_forward(*args)
    expected = manual_attn(*args)
    torch.testing.assert_close(result, expected)

    # Use opcheck to check for incorrect usage of operator registration APIs
    torch.library.opcheck(torch.ops.minimal_attn.mha_forward.default, args)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 32
#      28 samples.extend(sample_inputs(device, requires_grad=False))
#      29 for args in samples:
#      30     # Correctness test
#      31     # result = torch.ops.extension_cpp.mymuladd(*args)
# ---> 32     result = torch.ops.minimal_attn.mha_forward(*args)
#      33     expected = manual_attn(*args)
#      34     torch.testing.assert_close(result, expected)
#
# File /opt/conda/lib/python3.12/site-packages/torch/_ops.py:1225, in _OpNamespace.__getattr__(self, op_name)
#    1223     op, overload_names = _get_packet(qualified_op_name, module_name)
#    1224     if op is None:
# -> 1225         raise AttributeError(
#    1226             f"'_OpNamespace' '{self.name}' object has no attribute '{op_name}'"
#    1227         )
#    1228 except RuntimeError as e:
#    1229     # Turn this into AttributeError so getattr(obj, key, default)
#    1230     # works (this is called by TorchScript with __origin__)
#    1231     raise AttributeError(
#    1232         f"'_OpNamespace' '{self.name}' object has no attribute '{op_name}'"
#    1233     ) from e
#
# AttributeError: '_OpNamespace' 'minimal_attn' object has no attribute 'mha_forward'

# %% [markdown]
# ### HF

# %%
# We use our inline loaded version via torch, minimal_attn
from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2Model.from_pretrained("gpt2")
model.cuda()
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# GPT2Model(
#   (wte): Embedding(50257, 768)
#   (wpe): Embedding(1024, 768)
#   (drop): Dropout(p=0.1, inplace=False)
#   (h): ModuleList(
#     (0-11): 12 x GPT2Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPT2Attention(
#         (c_attn): Conv1D(nf=2304, nx=768)
#         (c_proj): Conv1D(nf=768, nx=768)
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): GPT2MLP(
#         (c_fc): Conv1D(nf=3072, nx=768)
#         (c_proj): Conv1D(nf=768, nx=3072)
#         (act): NewGELUActivation()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# )

# %% [markdown]
# ### Other Ideas
# We can try learning a regression model/small nn to give us the optimal block size under certain conditions. This can be something to show for -- we could just run gpt-2 a bunch of times and get an optimal version.

# %% [markdown]
# *Note in the future we can add torch.compile support for the operator.*
